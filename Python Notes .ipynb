# %%
#Read multiple numbers separated by spaces on the same line from the user.
#Change all spaces to a plus sign.
#Print the resulting string to the user.
# taking input and assigning to x

x = input('input numbers\n')

y = x.split(' ')

print('+'.join(y))

# %%
#Read input from the user, the input will be an integer.
#Determine which of the following categories the number fits into an print this to the user:

#Negative Even
#Negative Odd
#Zero
#Positive Even
#Positive Odd

#Wrapped the input in "int() to change it to an integer from a string"
x = int(input('give me an integer'))
if x == 0:
    print('Zero')
elif x>0 and x%2 == 0:
    print('Positive Even')
elif x>0 and x%2 == 1:
    print('Positive Odd')
elif x<0 and x%2 == 0:
    print('Negative Even')
elif x<0 and x%2 == 1:
    print('Negative Odd')

# %%
#Add code so that it takes a number from the user and prints it (the number) if it isn’t divisible by 3 or 5. 
# For multiples of 3 print 'fizz' instead. For multiples of 5 print 'buzz' instead. For multiples of 3 and 5 print 'fizzbuzz'.

x = int(input('Please input number!'))
#if not x%3 and not x%5:
if x%3 == 0 and x%5 == 0:
    print('fizzbuzz')
elif x%3 ==0:
    print('fizz')
elif x%5 ==0:
    print('buzz')
else:
    print(x)

# %%
def Multiply():
    sum = (x*2)
    return sum

x = 6

sum = Multiply()

print(sum)

# %%
#the below solution is using a user defined function to complete fizzbuzz.

def fizzbuzz(x):
    if x%3 == 0 and x%5 == 0:
        print('fizzbuzz')
    elif x%3 ==0:
        print('fizz')
    elif x%5 ==0:
        print('buzz')
    else:
        print(x)

fizzbuzz(5)

# %%
#Use python to produce code below that will perform the following:

#Create a function named domath that will accept 3 parameters.
#The function will add the first two parameters and multiply this sum by the third parameter.
#You can select the identifiers for each of the parameters.
#The resulting product will be returned to the caller.

def domath(x,y,z):
    sum = (x+y)*z
    return sum
    
domath(2,3,1)

# %%
x = 10
while x > 0:
    if x % 2:
        break
    print(x)
    x = x -1

print(x)

# %%
def fizzbuzz(x):
    x = int(x)
    if x%3 == 0 and x%5 == 0:
        print('fizzbuzz')
    elif x%3 ==0:
        print('fizz')
    elif x%5 ==0:
        print('buzz')
    else:
        print(x)

variable_1 = input('give me a number:')
while variable_1:
    print(fizzbuzz(variable_1))
    variable_1 = input('feed me seymor: ')

# %%
#range() will allow us to pass up to 3 arguments

#for i in range(5):
    #print(i)

for i in range(0,11,2):
    print(i)

# %%
#10

# Use python to produce code below that will perform the following:

# Read multiple lines from the user on standard input until an empty string is read.
# Return a list of all these lines without line terminators
# Each line should be reversed from how it is read in.

def reverseit():
    user_list = []
    user_input = input()
    while user_input:
        user_list.append(user_input[::-1])
        user_input = input()
    return user_list

# %%
#10

# Given a mixed case string as parameter s
# Capitalize every letter with an even index within the string.
# Lowercase every letter with an odd index within the string.
# Return the resulting string.
#Example - Given: "ABCDEF ghijkl" Return: "AbCdEf gHiJkL"

s = 'ABCDEF ghijkl'

def leetString(s):
    i=0
    new_string = ''
    for c in s:
        if i%2:
            new_sting = new_string+c.lower()
        else:
            new_string = new_string+c.upper()
    i = i+1
    return(new_sting)

# %%
#10 (Alternate)

s = 'ABCDEF ghijkl'
def leetString(s):
    new_string = ''
    for i in range(len(s)):
        if i%2:
            new_string = new_string + s[i].lower()
    else:
        new_string = new_string + s[i].upper()
    return(new_string)

# %%
#ooB

# Modify code below and implement guess_number so that it repeatedly asks the user for a number between 0 and 100, inclusive. 
# If the user correctly guesses the value of the given argument n, print 'WIN' and return. 
# Otherwise, indicate whether the guess was too high or too low.


def guess_number(n):
    #n = range(0,101)
    user_input = int(input('Give me a number between 0-100'))
    while user_input:
        if user_input == n:
            print('WIN')
            break
        elif user_input > n:
            print('too high')
            user_input = int(input('Give me another number between 0-100'))
        else:
            print('too low')
            user_input = int(input('Give me another number between 0-100'))

guess_number(23)

# %%
#11

# Use python to produce code below that will perform the following:
    # Print out every even number on a separate line from parameters first to last, inclusive.
    # Next print out every odd number from first to last, inclusive.

def evensandodds(first, last):
    #user_input_first = int(input('give me the first number in a range'))
    #user_input_last = int(input('give me the last number in a range'))
    #list_even
    #list_odd
    user_list = range(first, last+1)
    list_odd = []
    list_even = []
    #running a loop to separate even and odd numbers
    for i in user_list: #takes i one at a time from user list
        if i%2: #determine if i is odd
            list_odd.append(i)
        else: #i must be even 
            list_even.append(i)
    #print the even numbers that i separated in the step before
    for i in list_even:
        print(i)
    for i in list_odd:
        print(i)

# %%
#12

# def user_io():
#     '''
#     Returns a list of items read from the user until the user enters an empty string.

#     Args:
#         None
#     Returns:
#         list: a list of strings
#     '''    
#     pass


#check input from a user
#if uswer inputs something we need to create a list from the input
#return a list

def user_io():
    user_input = input('provide input or put nothing')
    user_list = []
    while user_input:
        user_list.append(user_input)
        user_input = input('provide input or put nothing')
    return user_list

# %%
#SLICING OBJECTS

s = 'this is a string'

s[3]

print(s[2:8:2]) # takes the string from index 2 through 8 and returns every other object

print(s[::-1]) # takes the entire string from start to end and returns the objects of the string backward

# %%
# randall.r.combs96@workstation12:~$ ls
# Desktop  Documents  Downloads  Music  Pictures  Public  Templates  Videos
# randall.r.combs96@workstation12:~$ nano test.txt
# randall.r.combs96@workstation12:~$ cat test.txt
# This is a test file
# This is for class CyOOC 23-001

# randall.r.combs96@workstation12:~$ python3
# Python 3.8.10 (default, Jun 22 2022, 20:18:18) 
# [GCC 9.4.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.

# >>> with open('test.txt') as fp:
# ...     fp.read()
# ... 
# 'This is a test file\nThis is for class CyOOC 23-001\n\n'
# >>> with open('test.txt') as fp:
# ...     fp.readline()
# ... 
# 'This is a test file\n'
# >>> with open('test.txt') as fp:
# ...     fp.readlines()
# ... 
# ['This is a test file\n', 'This is for class CyOOC 23-001\n', '\n'] - everything to the left of the "," is index 0 and everything to the right is index 1
# >>> 
# >>> with open('test.txt') as fp:
# ...     fp.read(8)
# ... 
# 'This is '
# >>> 
# >>> with open('test.txt') as fp:
# ...     fp.readlines()[1]
# ... 
# 'This is for class CyOOC 23-001\n'

# %%
# def make_tuple():
#     '''
#      Returns a tuple of the multiples of 10 from 1 to 100 inclusive.
#      Args:
#          None
#      Returns:
#          tuple: a tuple of the multiples of 10 from 1 to 100 inclusive
#      '''
#      pass  


def make_tuple():
    user_list = list(range(10,101,10)) # the user_list is a range of numbers starting with 10 going THROUGH 100 by multiples of 10
    user_tup = tuple(user_list) # change user_list to a tuple
    return(user_tup) # must return the tup at the end of the user function

make_tuple()

# %%
# def make_tuple(a,b):
#     '''
#     Returns a tuple of the multiples of 10 from a to b inclusive.
#     Args:
#         None
#     Returns:
#         tuple: a tuple of the multiples of 10 from a to b inclusive
#     '''    

#user defines range (a through b)
#return that list in multiples of 10 but must be inclusive 

def make_tuple(a,b):
    user_range = list(range(a, b+1))
    user_range_2 = []
    for i in user_range:
        if i % 10 == 0:
            user_range_2.append(i)
    user_tuple = tuple(user_range_2)
    return(user_tuple)


make_tuple(20,80)

# %%
# def strings():
#     '''
#     Returns a tuple of the following two strings:

    

#     Physics is the universe's operating system

#     Args:
#         None
#     Returns:
#         tuple: a tuple of strings
#      '''
#     pass

#() around a string automatically turns it into a tuple....done

def strings():
    tup = ("", "Physics is the universe's operating system")
    return tup

# %%
#15

# def disect(lst):
#     '''
#     Returns a tuple of the given list split into two equally sized halves.
#     The given list will always consist of an even number of elements.
#     Args:
#         lst (lst): a list of elements
#     Returns:
#         tuple: a tuple of two lists
#     '''
#     pass    

# even number of objects in a list and split that list in half

def disect(lst):
    x = len(lst)
    x = int(x) #must change x to an integer 
    new_list_2 = lst[0:(x//2)] #double // is no-remainder division
    new_list_3 = lst[(x//2):x]
    return (new_list_2, new_list_3)

    print(new_list_2)
    print(new_list_3)


a = [10,20,30,40]
disect(a)
disect([10,20,30,40])
# Out:
# ([10, 20], [30, 40])
